# %% [markdown]
# # First steps
# * PySpark Dataframe
# * Reading The Dataset
# * Checking the Datatypes of the Column(Schema)
# * Selecting Columns And Indexing
# * Check Describe option similar to Pandas
# * Adding Columns
# * Dropping columns
# * Renaming Columns

# %% [markdown]
# # Check assumptions

# %% [markdown]
# # Error no catalog
#
# utilizar where ou which python com o environment ativo
#
# ```bash
# which python
# ```
# ```bash
# where python
# ```
#
# Na localização encontrada adicionar Lib\site-packages\pyspark\jars

# %%
import pyspark

# %%
pyspark.__version__
# Out:
# '4.1.1'

# %%
#import findspark
#findspark.init()

# %% [markdown]
# Se der erro:
#
# ```Py4JJavaError: An error occurred while calling None.org.apache.spark.api.java.JavaSparkContext.
# : java.net.BindException: Cannot assign requested address: bind: Service 'sparkDriver' failed after 16 retries (on a random free port)! Consider explicitly setting the appropriate binding address for the service 'sparkDriver' (for example spark.driver.bindAddress for SparkDriver) to the correct binding address```

# %%
conf = pyspark.SparkConf().set('spark.driver.host','localhost')

# %%
# Import PySpark and create a SparkSession
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("ImportData").getOrCreate()

#spark = SparkSession.builder \
#    .appName("ImportData") \
#    .config("spark.executor.memory", "4g") \
#    .getOrCreate()
# Out:
# /home/sobreiro/miniconda3/envs/bigdata/lib/python3.11/site-packages/pyspark/bin/spark-class: line 71: /home/sobreiro/miniconda3/lib/jvm/bin/java: No such file or directory
# /home/sobreiro/miniconda3/envs/bigdata/lib/python3.11/site-packages/pyspark/bin/spark-class: line 97: CMD: bad array subscript
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Import PySpark and create a SparkSession
#       2 from pyspark.sql import SparkSession
# ----> 4 spark = SparkSession.builder.appName("ImportData").getOrCreate()
#       6 #spark = SparkSession.builder \
#       7 #    .appName("ImportData") \
#       8 #    .config("spark.executor.memory", "4g") \
#       9 #    .getOrCreate()
#
# File ~/miniconda3/envs/bigdata/lib/python3.11/site-packages/pyspark/sql/session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File ~/miniconda3/envs/bigdata/lib/python3.11/site-packages/pyspark/core/context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File ~/miniconda3/envs/bigdata/lib/python3.11/site-packages/pyspark/core/context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File ~/miniconda3/envs/bigdata/lib/python3.11/site-packages/pyspark/core/context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File ~/miniconda3/envs/bigdata/lib/python3.11/site-packages/pyspark/java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %%
spark
# Out:
# 26/04/18 12:51:42 WARN SharedState: Cannot qualify the warehouse path, leaving it unqualified.
# java.lang.UnsupportedOperationException: getSubject is not supported
# 	at java.base/javax.security.auth.Subject.getSubject(Subject.java:277)
# 	at org.apache.hadoop.security.UserGroupInformation.getCurrentUser(UserGroupInformation.java:588)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3888)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3878)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:3666)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:557)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:366)
# 	at org.apache.spark.sql.internal.SharedState$.qualifyWarehousePath(SharedState.scala:302)
# 	at org.apache.spark.sql.internal.SharedState.liftedTree1$1(SharedState.scala:82)
# 	at org.apache.spark.sql.internal.SharedState.<init>(SharedState.scala:81)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sharedState$1(SparkSession.scala:176)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.classic.SparkSession.sharedState$lzycompute(SparkSession.scala:176)
# 	at org.apache.spark.sql.classic.SparkSession.sharedState(SparkSession.scala:175)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sessionState$2(SparkSession.scala:187)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.classic.SparkSession.sessionState$lzycompute(SparkSession.scala:185)
# 	at org.apache.spark.sql.classic.SparkSession.sessionState(SparkSession.scala:182)
# 	at org.apache.spark.sql.classic.SparkSession.conf$lzycompute(SparkSession.scala:198)
# 	at org.apache.spark.sql.classic.SparkSession.conf(SparkSession.scala:198)
# 	at org.apache.spark.sql.classic.SparkSession.conf(SparkSession.scala:92)
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:104)
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:565)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:184)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:108)
# 	at java.base/java.lang.Thread.run(Thread.java:1474)
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.16.21.134:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>ImportData</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Comandos jupyter notebook
#
#
# * a = above abre célula acima
# * b = bellow abre célula abaixo
# * dd = apaga célula
# * x corta célula
# * v cola célula
# * m modo markdown
# * y modo código
#
# # Markdown
#
# * \# Titulo 1
# * \## Titulo 2
# * \* unnumbered bullet
# * \1. numbered bullet
#
# 1. Item
# 2. Item
# 3. Item
#
# [Google](http://www.google.com)

# %% [markdown]
# # Dados disponíveis no repositório
#
# * O dataset `btc_04h_usdt_binance.parquet` já está incluído no projeto
# * Formato Parquet — otimizado para Big Data (columnar, comprimido)

# %%
# linux/mac
# !pwd
# windows
# !cd

# %%
import pandas as pd

df_pandas = pd.read_parquet("./../data/btc_04h_usdt_binance.parquet")

# %%
type(df_pandas)

# %%
df_pandas.describe()

# %%
df_pandas.head()

# %%
df_pandas.info()

# %%
spark

# %%
# Ler dados BTC em formato Parquet (dados reais da Binance)
df_btc = spark.read.parquet("./../data/btc_04h_usdt_binance.parquet")

# %%
type(df_pandas)

# %%
type(df_btc)

# %%
df_btc.head(5)

# %%
df_btc.show(5)

# %%
df_btc.toPandas().head()

# %%
type(df_btc.toPandas().head())

# %%
df_btc.sample(fraction=0.1).toPandas().head()

# %%
df_btc.show(5)

# %%
df_btc.tail(5)

# %%
# Mostrar as colunas de open_time e preço de fecho
df_btc[['open_time','close']].show(10)

# %%
df_btc.take(4)

# %%
df_btc.describe().toPandas()

# %%
df_btc.take(1)

# %%
df_btc.explain()

# %% [markdown]
# # Exemplo com pyspark.pandas
#
# Advantages of pyspark.pandas over pandas:
#
# * Scalability: The biggest advantage is its ability to handle datasets that are far too large to fit into the memory of a single machine. pyspark.pandas leverages the power of Apache Spark to distribute data and computations across a cluster of machines, enabling processing of massive datasets that would overwhelm pandas.
# * Distributed Computing: By distributing workloads, pyspark.pandas can often achieve significantly faster processing times than pandas on large datasets. This is especially beneficial for tasks like complex aggregations, joins, or machine learning algorithms.
# * Integration with Spark Ecosystem: pyspark.pandas seamlessly integrates with other components of the Spark ecosystem, such as Spark SQL for querying structured data, Spark Streaming for real-time processing, and MLlib for machine learning. This makes it easier to build end-to-end big data pipelines.
# * Familiarity: The API of pyspark.pandas is intentionally designed to be very similar to pandas, making it easier for data scientists familiar with pandas to transition to big data analysis.
# * pyspark.pandas: The preferred choice for large-scale datasets that exceed the memory capacity of a single machine. It provides scalability, distributed computing capabilities, and integration with the broader Spark ecosystem.

# %%
import pyspark.pandas as ps

df_btc_pandas = ps.DataFrame(df_btc)

# %%
df_btc_pandas.head()

# %%
df_btc_pandas.describe()

# %%
df_btc_pandas.dtypes

# %% [markdown]
# # Vamos criar uma vista temporária para os dados para pudermos utilizar num comando SQL

# %%
df_btc.createOrReplaceTempView("xico")

# %% [markdown]
# # Vamos confirmar as vistas criadas

# %%
spark.catalog.listTables()

# %%
sql = spark.sql(""" SELECT * FROM xico WHERE close > 50000 """)

# %%
df_btc.createOrReplaceTempView("xico2")

# %%
sql2 = spark.sql(""" SELECT * FROM xico2 WHERE close > 40000 """)

# %%
spark.catalog.listTables()

# %%
sql.show()

# %% [markdown]
# # Adicionar uma coluna ao dataframe
#
# Vamos calcular a moving average 7 dias

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import col, avg

window = Window.orderBy('open_time').rowsBetween(-7, 0)
df_btc = df_btc.withColumn('ma7', avg('close').over(window))

# %%
df_btc.show()

# %% [markdown]
# ```
# partitionBy = controla as linhas que ficam na mesma partição. Se estivermos num ambiente distribuido é importante que por exemplo os mesmos symbols sejam processados na mesmo equipamento.
# ```

# %% [markdown]
# # Vamos fazer o drop de uma coluna
#
# Para tornar a alteração assigna-se novamente ao Spark Dataframe. No pandas temos inplace=True

# %%
df_btc.drop('ma7').show()

# %% [markdown]
# # Mudar o nome a uma coluna

# %%
df_btc.withColumnRenamed('ma7','moving_average_7').show()

# %%
df = df_btc.withColumnRenamed('ma7','moving_average_7').show()

# %%
df_btc.show()

# %%
df_btc = df_btc.withColumnRenamed('ma7','moving_average_7')

# %%
df_btc.show()

# %%
# Stop the SparkSession
spark.stop()
